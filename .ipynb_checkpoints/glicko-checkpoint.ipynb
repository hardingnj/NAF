# %%
# !pip install git+git://github.com/sublee/glicko2.git
# Out:
# The directory '/home/njh/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# The directory '/home/njh/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting git+git://github.com/sublee/glicko2.git
#   Cloning git://github.com/sublee/glicko2.git to /tmp/pip-72wl53fz-build
#   Requirement already satisfied (use --upgrade to upgrade): glicko2==0.0.dev0 from git+git://github.com/sublee/glicko2.git in /usr/local/lib/python3.5/dist-packages
# Requirement already satisfied (use --upgrade to upgrade): distribute in /usr/local/lib/python3.5/dist-packages (from glicko2==0.0.dev0)
# Requirement already satisfied (use --upgrade to upgrade): setuptools>=0.7 in /usr/local/lib/python3.5/dist-packages (from distribute->glicko2==0.0.dev0)
# You are using pip version 8.0.2, however version 8.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import glicko2 as Glicko

# %%
# improbable results are likely so set tau low
tau = 0.3
phi = 250
glck = Glicko.Glicko2(tau=tau, phi=250, sigma=0.2)

# %%
import pandas as pd
import math
import numpy as np

# %%
naf_data = pd.read_csv("data/NAF_games.csv.gz", sep=";", 
                       parse_dates=['gamedate'], index_col=1)

naf_data.sort_values("gamedate", inplace=True)

# %%
naf_data.head()
# Out:
#        tournamentnation  HomeCoachNAFid    HomeRace  goalshome  \
# gameid
# 8572        Netherlands             152  Wood Elves          1
# 8499        Netherlands              36         Orc          1
# 8498        Netherlands             127      Humans          3
# 8497        Netherlands              57      Undead          1
# 8496        Netherlands             129  High Elves          2
#
#         AwayCoachNAFid    AwayRace  goalsaway   gamedate
# gameid
# 8572               126  Dark Elves          5 2003-01-02
# 8499               146       Norse          2 2003-01-02
# 8498               134         Orc          3 2003-01-02
# 8497               151         Orc          2 2003-01-02
# 8496               152  Wood Elves          1 2003-01-02

# %%
# create lookup table
# inefficient, but hey ho
dd = pd.read_csv("data/NAFgames.csv")
lookup = dict()

for i, row in dd.iterrows():
    lookup[row.HomeCoachNAFid] = row.HomeCoachNAFname
    lookup[row.AwayCoachNAFid] = row.AwayCoachNAFname

# %%
ranking_periods = pd.date_range(naf_data.iloc[0].gamedate - pd.offsets.MonthBegin(1), 
                                naf_data.iloc[-1].gamedate + pd.offsets.MonthBegin(1), 
                                freq='1M')

# %%
counter=0
ranking_data = dict()

for start, stop in zip(ranking_periods[:-1], ranking_periods[1:]):
    
    new_ranking = dict()
    
    start_ix = naf_data.gamedate.searchsorted(start)
    stop_ix = naf_data.gamedate.searchsorted(stop)
    
    d = naf_data[start_ix:stop_ix]
    
    x = d.drop(["tournamentnation", "gamedate"], axis=1).copy()
    y = x.ix[:, [3, 4, 5, 0, 1, 2]].copy()
    
    y.columns = x.columns
    x = pd.concat([x, y], axis=0)

    x["result"] = np.where(x.goalshome > x.goalsaway, 1, 
                           np.where(x.goalshome < x.goalsaway, 0, 0.5)) 
    
    grped = x.groupby("HomeCoachNAFid")
    
    # first run through all players who have played in this period
    for player in grped.groups:
        
        
        new_ranking[player] = dict()
        data = grped.get_group(player)
        
        if player not in ranking_data:
            ranking_data[player] = dict()
            
        # now loop through races...
        byrace = data.groupby("HomeRace")
        for played_race in byrace.groups:

            games = byrace.get_group(played_race)
            series = list()

            for oppo_id, oppo_race, result in zip(games.AwayCoachNAFid, 
                                                  games.AwayRace, games.result):

                if oppo_id not in ranking_data:
                    ranking_data[oppo_id] = dict()

                if oppo_race not in ranking_data[oppo_id]:
                    ranking_data[oppo_id][oppo_race] = glck.create_rating()

                series.append((result, ranking_data[oppo_id][oppo_race]))

            # now rate
            if played_race not in ranking_data[player]:
                ranking_data[player][played_race] = glck.create_rating()

            new_ranking[player][played_race] = glck.rate(ranking_data[player][played_race], series)

    # now through all players: if not played then increment their phi
    for player, rankings in ranking_data.items():
        
        assert len(rankings) > 0
            
        for race, rank in rankings.items():
            played = False
        
            if player not in new_ranking:
                # if not in new ranking, then cannot have played...
                new_ranking[player] = dict()
                
            if player in grped.groups:
                # might have played
                data = grped.get_group(player)
                byrace = data.groupby("HomeRace")
                if race in byrace.groups:
                    played = True
                
            if not played:
                # if he/she didn't play
                
                
                dnp = glck.scale_down(ranking_data[player][race])
                phi_star = math.sqrt(dnp.phi ** 2 + dnp.sigma ** 2)
                new_ranking[player][race] = glck.scale_up(
                    glck.create_rating(mu=dnp.mu, phi=phi_star, sigma=dnp.sigma))
                
#                 if (player == 149) and (race == "Amazons"):
#                     print(start, dnp.phi, phi_star, race)
                
    ranking_data = new_ranking
#    print(counter)
    counter += 1

# %%
d = list()

# for each player
for key, value in ranking_data.items():
    
    races = value.keys()
    pid = lookup.get(key, str(key))
    
    index = pd.MultiIndex.from_tuples([(pid, r) for i, r in enumerate(races)])
    
    df = pd.DataFrame(index=index, columns=["mu", "phi", "sigma"])
    
    # for each race played...
    for race in races:
        q = ranking_data[key][race]
        df.loc[pid, race] = (q.mu, q.phi, q.sigma)
    d.append(df)

# %%
combined_rankings = pd.concat(d)

# %%
combined_rankings["rating"] = combined_rankings.mu - 2*combined_rankings.phi

# %%
combined_rankings.sort_values("rating", inplace=True, ascending=False)

# %%
combined_rankings[:50]
# Out:
#                                 mu      phi     sigma   rating
# Jimjimany   Wood Elves     2057.47  119.484  0.198862   1818.5
# Purplegoo   Humans         1960.22  107.512  0.199445   1745.2
# Spartako    Wood Elves     1889.09  85.7236  0.198982  1717.64
# Tank        Orc            1911.46  108.889  0.199603  1693.68
# Geggster    Amazons        1944.43  135.494  0.199778  1673.44
# Itzla       Lizardmen      1951.22  139.994  0.199542  1671.23
# Dirold      Amazons        1931.82  131.443  0.199576  1668.93
# Matte83     Lizardmen      1878.45  106.475  0.199789   1665.5
# Dirold      Dark Elves     1856.31  95.4716  0.199555  1665.37
# Knox        Undead         1861.29  99.9816  0.199837  1661.32
# le_troll    Dwarves        1860.78  100.083  0.199203  1660.61
# Joemanji    Wood Elves     1883.69  111.618  0.199534  1660.45
# Purplegoo   Wood Elves     1907.53  124.331  0.199457  1658.87
# Titouch     Wood Elves     1888.96  116.775  0.199545  1655.41
# Pippy       Norse          1923.33  135.232  0.199874  1652.87
# BiBi        Lizardmen      1877.58  113.264  0.199969  1651.06
# Pako        Dark Elves     1924.68  137.589  0.199719   1649.5
# Harti       Chaos Dwarves  1892.78  122.036  0.198925  1648.71
# Rolex       Chaos Dwarves   1931.3  143.813  0.199767  1643.68
# bud_wiser   Dark Elves     1864.71   111.53  0.199739  1641.65
# Roller      Dwarves        1872.14  116.054  0.199135  1640.03
# Dirold      Chaos Dwarves  1873.56  116.993  0.200027  1639.58
# Simon_MLF   Wood Elves     1853.07  106.784  0.200138   1639.5
# Bucks       Wood Elves     1835.08  98.7194  0.198495  1637.64
# MissSweden  Chaos Pact     1854.35  108.697  0.199698  1636.96
# D_Arquebus  Orc             1904.8  134.003  0.199718   1636.8
# delevus     Amazons        1875.87  119.711  0.199493  1636.45
# MattRobson  Lizardmen       2026.5  195.754  0.200039  1634.99
# Geggster    Dark Elves     1909.33  137.293  0.199809  1634.75
# Matt_le_Fou Amazons        1865.02  116.388  0.199503  1632.24
# Elyoukey    Dark Elves     1902.45  136.726  0.199799     1629
# Matt_le_Fou Undead         1891.05  131.131  0.199856  1628.79
# Kithor      Amazons        1882.02  126.737  0.199282  1628.55
# Harti       High Elves      1904.9  138.507  0.199997  1627.89
# Purplegoo   Slann          1955.35  164.734  0.200191  1625.88
# Podfrey     Dwarves        1890.72   132.54  0.199301  1625.64
# odul        Dark Elves     1974.41   176.53  0.200323  1621.35
# Sizzler     Undead         1976.56  178.191  0.200251  1620.17
# Simon_MLF   Norse          1825.93  103.362  0.198833   1619.2
# Jeff        Chaos Pact     1859.59  120.935  0.199756  1617.72
# Roller      Wood Elves      1882.3  132.471  0.200084  1617.35
# BiBi        Wood Elves     1896.89  140.923  0.199691  1615.04
# Liam        Undead         1778.52  82.6341  0.197385  1613.25
# Farina      Skaven         1772.69  81.5236  0.199182  1609.64
# Thomsy      Dark Elves      1967.2  179.047  0.200148  1609.11
# Joemanji    Dark Elves     1818.45  106.455  0.199391  1605.54
# Pippy       Lizardmen      1834.69  114.906  0.198805  1604.87
# Cana        Orc            1758.29  76.7115  0.198814  1604.87
# Masterfit   Orc            1857.74   127.25  0.199869  1603.24
# Rolex       Humans         1767.18  82.6753   0.19947  1601.83

# %%
combined_rankings.xs("mubo")
# Out:
#                   mu      phi     sigma   rating
# Wood Elves   1889.06  191.673  0.199835  1505.71
# Dark Elves   1904.59  221.991  0.200005  1460.61
# Elves        1737.69  195.761   0.19998  1346.17
# Undead       1778.08  225.357  0.200099  1327.36
# Skaven        1812.9  258.224   0.19958  1296.45
# Humans       1556.54  155.089  0.199899  1246.36
# Orc          1679.09  247.269  0.199997  1184.55
# Dwarves      1651.38  299.316       0.2  1052.75
# Chaos Pact   1502.03  287.527  0.199941  926.973
# Necromantic  1520.71  299.982  0.199915  920.749
# Norse        1443.21  272.178  0.199949   898.85

# %%
# algorithm:

# grab data in rating period. 2 months.

# reshape the data so 2 x the number of rows and home/away repeated. column for w/l/d
# 3 columns, playerID, oppoent, result

# group df by playerA id. 

# create a matrix of all the players who compet
